# %%
from PIL import Image
import numpy as np

pics_path = '/home/ivanwilliam/Documents/Full_images/1.0/AGFA000000007423_Lung 1.0/AGFA000000007423_0144.jpg'
picture_ds = Image.open(pics_path)
pics_array= np.array(picture_ds)

print("debug R")
print('1. ' +str(np.max(pics_array[:,:,0]))+'\n')
print('2. ' +str(np.max(pics_array[:,256,0]))+'\n')
print('3. ' +str(np.min(pics_array[:,:,0]))+'\n')
print('4. ' +str(np.min(pics_array[:,256,0]))+'\n')
print('5. ' +str(np.mean(pics_array[:,:,0]))+'\n')
print('6. ' +str(np.mean(pics_array[:,256,0]))+'\n')
print('7. ' +str(np.mean(pics_array[:,:,0]))+'\n')
print('8. ' +str(np.mean(pics_array[:,256,0]))+'\n')

print("debug G")
print('1. ' +str(np.max(pics_array[:,:,1]))+'\n')
print('2. ' +str(np.max(pics_array[:,256,1]))+'\n')
print('3. ' +str(np.min(pics_array[:,:,1]))+'\n')
print('4. ' +str(np.min(pics_array[:,256,1]))+'\n')
print('5. ' +str(np.mean(pics_array[:,:,1]))+'\n')
print('6. ' +str(np.mean(pics_array[:,256,1]))+'\n')
print('7. ' +str(np.mean(pics_array[:,:,1]))+'\n')
print('8. ' +str(np.mean(pics_array[:,256,1]))+'\n')

print("debug B")
print('1. ' +str(np.max(pics_array[:,:,2]))+'\n')
print('2. ' +str(np.max(pics_array[:,256,2]))+'\n')
print('3. ' +str(np.min(pics_array[:,:,2]))+'\n')
print('4. ' +str(np.min(pics_array[:,256,2]))+'\n')
print('5. ' +str(np.mean(pics_array[:,:,2]))+'\n')
print('6. ' +str(np.mean(pics_array[:,256,2]))+'\n')
print('7. ' +str(np.mean(pics_array[:,:,2]))+'\n')
print('8. ' +str(np.mean(pics_array[:,256,2]))+'\n')
# Out:
# debug R
# 1. 255
#
# 2. 255
#
# 3. 0
#
# 4. 6
#
# 5. 82.26639556884766
#
# 6. 125.75390625
#
# 7. 82.26639556884766
#
# 8. 125.75390625
#
# debug G
# 1. 255
#
# 2. 255
#
# 3. 0
#
# 4. 6
#
# 5. 82.26639556884766
#
# 6. 125.75390625
#
# 7. 82.26639556884766
#
# 8. 125.75390625
#
# debug B
# 1. 255
#
# 2. 255
#
# 3. 0
#
# 4. 6
#
# 5. 82.26639556884766
#
# 6. 125.75390625
#
# 7. 82.26639556884766
#
# 8. 125.75390625

# %%
import glob
import os
import PIL
import numpy as np
import h5py
import IPython 
from PIL import Image

# try:
#     import Image
# except ImportError:
#     from PIL import Image

hdf5_path = '/media/ivanwilliam/BINUS_DATA/i3d_hdf5_lung_data/HDF5_File/AGFA000000007423_Lung 1.0_005.h5'
k=5

hdf_check=h5py.File(hdf5_path, 'r')
base_items = list (hdf_check.items())
dataset=hdf_check.get('dataset')

a = len(dataset)
print (a)

o=145

x=(k-1)*32
i=x

dataset_debug=dataset[o-x-1]
print("debug R")
print('1. ' +str(np.max(dataset_debug[:,:,0]))+'\n')
print('2. ' +str(np.max(dataset_debug[:,256,0]))+'\n')
print('3. ' +str(np.min(dataset_debug[:,:,0]))+'\n')
print('4. ' +str(np.min(dataset_debug[:,256,0]))+'\n')
print('5. ' +str(np.mean(dataset_debug[:,:,0]))+'\n')
print('6. ' +str(np.mean(dataset_debug[:,256,0]))+'\n')
print('7. ' +str(np.mean(dataset_debug[:,:,0]))+'\n')
print('8. ' +str(np.mean(dataset_debug[:,256,0]))+'\n')


# for i in range (x,x+32):
#     img_data= PIL.Image.fromarray(dataset[i-x])
#     img_data.save('img_data'+str(i+1)+'.jpg')
#     i=i+1
#     img_data.show()
# Out:
# 32
# debug R
# 1. 255
#
# 2. 255
#
# 3. 0
#
# 4. 6
#
# 5. 82.26639556884766
#
# 6. 125.75390625
#
# 7. 82.26639556884766
#
# 8. 125.75390625

# %%
from PIL import Image
import numpy as np

pics_path2 = '/home/ivanwilliam/0. MINIProject (06-03-2019)/32images_hdf5converter/img_data144.jpg'
picture_ds2 = Image.open(pics_path2)
pics_array2= np.array(picture_ds2)

# %%
print("debug R")
print('1. ' +str(np.max(pics_array2[:,:,0]))+'\n')
print('2. ' +str(np.max(pics_array2[:,256,0]))+'\n')
print('3. ' +str(np.min(pics_array2[:,:,0]))+'\n')
print('4. ' +str(np.min(pics_array2[:,256,0]))+'\n')
print('5. ' +str(np.mean(pics_array2[:,:,0]))+'\n')
print('6. ' +str(np.mean(pics_array2[:,256,0]))+'\n')
print('7. ' +str(np.mean(pics_array2[:,:,0]))+'\n')
print('8. ' +str(np.mean(pics_array2[:,256,0]))+'\n')

print("debug G")
print('1. ' +str(np.max(pics_array2[:,:,1]))+'\n')
print('2. ' +str(np.max(pics_array2[:,256,1]))+'\n')
print('3. ' +str(np.min(pics_array2[:,:,1]))+'\n')
print('4. ' +str(np.min(pics_array2[:,256,1]))+'\n')
print('5. ' +str(np.mean(pics_array2[:,:,1]))+'\n')
print('6. ' +str(np.mean(pics_array2[:,256,1]))+'\n')
print('7. ' +str(np.mean(pics_array2[:,:,1]))+'\n')
print('8. ' +str(np.mean(pics_array2[:,256,1]))+'\n')

print("debug B")
print('1. ' +str(np.max(pics_array2[:,:,2]))+'\n')
print('2. ' +str(np.max(pics_array2[:,256,2]))+'\n')
print('3. ' +str(np.min(pics_array2[:,:,2]))+'\n')
print('4. ' +str(np.min(pics_array2[:,256,2]))+'\n')
print('5. ' +str(np.mean(pics_array2[:,:,2]))+'\n')
print('6. ' +str(np.mean(pics_array2[:,256,2]))+'\n')
print('7. ' +str(np.mean(pics_array2[:,:,2]))+'\n')
print('8. ' +str(np.mean(pics_array2[:,256,2]))+'\n')
# Out:
# debug R
# 1. 255
#
# 2. 255
#
# 3. 0
#
# 4. 4
#
# 5. 82.25893020629883
#
# 6. 125.1796875
#
# 7. 82.25893020629883
#
# 8. 125.1796875
#
# debug G
# 1. 255
#
# 2. 255
#
# 3. 0
#
# 4. 4
#
# 5. 82.25893020629883
#
# 6. 125.1796875
#
# 7. 82.25893020629883
#
# 8. 125.1796875
#
# debug B
# 1. 255
#
# 2. 255
#
# 3. 0
#
# 4. 4
#
# 5. 82.25893020629883
#
# 6. 125.1796875
#
# 7. 82.25893020629883
#
# 8. 125.1796875
